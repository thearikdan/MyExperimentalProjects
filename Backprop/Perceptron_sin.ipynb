# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np
from random import uniform
import math

# %%
def inp(w, x, b):
    return w * x + b


def out(t):
    return np.tanh(t)


def nueron(w, x, b):
    return out(inp(w, x, b))


def tanh_deriv(x):
    t = np.tanh(x)**2
    return 1.0 - t


def neuron_der_b(w, x, b):
    


def pred(x, w11_x, w11_b, w12_x, w12_b, w21_x, w22_x, w2_b):
    return (w21_x * neuron(w11_x, x, w11_b) + w22_x * neuron(w12_x, x, w12_b) + w2_b)


def func(x):
    return np.sin(x)


def loss(x, w11_x, w11_b, w12_x, w12_b, w21_x, w22_x, w2_b):
    l = 0
    for item in x:
        f = func(item)
        p = pred(x, w11_x, w11_b, w12_x, w12_b, w21_x, w22_x, w2_b)
        sq = (p - func(item)) * (p - func(item))
        l = l + sq
    print "Loss = " + str(l)
    return l


def loss_deriv_w2_b(x, w11_x, w11_b, w12_x, w12_b, w21_x, w22_x, w2_b):
    l = 0
    for item in x:
        f = func(item)
        p = pred(item, w11_x, w11_b, w12_x, w12_b, w21_x, w22_x, w2_b)
        sq = 2 * (p - func(item))
        l = l + sq
    print "Loss_deriv_w2_b = " + str(l)
    return l
    
    
def loss_deriv_w21_x(x, w11_x, w11_b, w12_x, w12_b, w21_x, w22_x, w2_b):
    l = 0
    for item in x:
        f = func(item)
        p = pred(item, w11_x, w11_b, w12_x, w12_b, w21_x, w22_x, w2_b)
        sq = 2 * (p - func(item)) * neuron(w11_x, item, w11_b)
        l = l + sq
    print "Loss_derivv_w21_x = " + str(l)
    return l    


def loss_deriv_w22_x(x, w11_x, w11_b, w12_x, w12_b, w21_x, w22_x, w2_b):
    l = 0
    for item in x:
        f = func(item)
        p = pred(item, w11_x, w11_b, w12_x, w12_b, w21_x, w22_x, w2_b)
        sq = 2 * (p - func(item)) * neuron(w21_x, item, w21_b)
        l = l + sq
    print "Loss_derivv_w21_x = " + str(l)
    return l    


def loss_deriv_w11_b(x, w11_x, w11_b, w12_x, w12_b, w21_x, w22_x, w2_b):
    l = 0
    for item in x:
        f = func(item)
        p = pred(item, w11_x, w11_b, w12_x, w12_b, w21_x, w22_x, w2_b)
        sq = 2 * (p - func(item)) * neuron(w21_x, item, w21_b)
        l = l + sq
    print "Loss_derivv_w21_x = " + str(l)
    return l    

#def loss_deriv_lin_w11_x(x, w11_x, w12_x, w_b):
#    l = 0
#    for item in x:
#        sq = 2 * (w11 * item + w12 * item + w2 - func(item)) * w11
#        l = l + sq
#    return l

#def loss_deriv_lin_w12_x(x, w11_x, w12_x, w_b):
#    l = 0
#    for item in x:
#        sq = 2 * (w11 * item + w12 * item + w2 - func(item)) * w12
#        l = l + sq
#    return l

#def loss_deriv_lin_w_b(x, w11_x, w12_x, w_b):
#    l = 0
#    for item in x:
#        sq = 2 * (w11 * item + w12 * item + w2 - func(item))
#        l = l + sq
#    return l


#def loss_deriv_w_b(x1, x2, w11, w12, w_b):
#    l = 0
#    for item in x:
#        sq = 2 * (w11 * x1 + w12 * x2 + w2 - func(item))
#        l = l + sq
#    print "Loss_deriv_w_b = " + str(l)
#    return l

# %%
epochs = 1000
step_tanh_w_x = 0.25
step_tanh_w_b = 0.05
step_lin_w_x = 0.25
step_lin_w_b = 0.05
x = np.arange(0, math.pi, 0.05)
print x
y = func(x)
print y

w11_x = uniform(0, 1)
w11_b = uniform(0, 1)

w12_x = uniform(0, 1)
w12_b = uniform(0, 1)

w21_x = uniform(0, 1)
w22_x = uniform(0, 1)

w2_b  = uniform(0, 1)
# Out:
# [ 0.    0.05  0.1   0.15  0.2   0.25  0.3   0.35  0.4   0.45  0.5   0.55
#   0.6   0.65  0.7   0.75  0.8   0.85  0.9   0.95  1.    1.05  1.1   1.15
#   1.2   1.25  1.3   1.35  1.4   1.45  1.5   1.55  1.6   1.65  1.7   1.75
#   1.8   1.85  1.9   1.95  2.    2.05  2.1   2.15  2.2   2.25  2.3   2.35
#   2.4   2.45  2.5   2.55  2.6   2.65  2.7   2.75  2.8   2.85  2.9   2.95
#   3.    3.05  3.1 ]
# [ 0.          0.04997917  0.09983342  0.14943813  0.19866933  0.24740396
#   0.29552021  0.34289781  0.38941834  0.43496553  0.47942554  0.52268723
#   0.56464247  0.60518641  0.64421769  0.68163876  0.71735609  0.75128041
#   0.78332691  0.8134155   0.84147098  0.86742323  0.89120736  0.91276394
#   0.93203909  0.94898462  0.96355819  0.97572336  0.98544973  0.99271299
#   0.99749499  0.99978376  0.9995736   0.99686503  0.99166481  0.98398595
#   0.97384763  0.9612752   0.94630009  0.92895972  0.90929743  0.88736237
#   0.86320937  0.83689879  0.8084964   0.7780732   0.74570521  0.71147335
#   0.67546318  0.6377647   0.59847214  0.55768372  0.51550137  0.47203054
#   0.42737988  0.38166099  0.33498815  0.28747801  0.23924933  0.19042265
#   0.14112001  0.09146464  0.04158066]

# %%
fig,(ax1, ax2, ax3, ax4) = plt.subplots(4,1, sharex = False, sharey = False)

ax1.set_xlabel('X')
ax1.set_ylabel('Y')
ax1.set_xlim(0, math.pi)
ax1.set_ylim(-2, 2)
ax1.set_xlabel("X")
ax1.plot(x, y, color = 'r')

ax2.set_xlabel("Step")
ax2.set_ylabel("Loss")
ax2.set_xlim(0, epochs)
ax2.set_ylim(0, 0.5)

ax3.set_xlabel("Step")
ax3.set_ylabel("w_x")
ax3.set_xlim(0, epochs)
ax3.set_ylim(-1, 1)

ax4.set_xlabel("Step")
ax4.set_ylabel("w_b")
ax4.set_xlim(0, epochs)
ax4.set_ylim(-1, 1)
# Out:
# <img src="data:image/png;base64,..." width="640">
# (-1, 1)

# %%
for i in range(epochs):
    l = loss(x, w11_x, w11_b, w12_x, w12_b, w21_x, w22_x, w2_b)
    ax2.scatter(i, l, color = 'r', s=5)
    
    x1 = tanh(w11_x * x + w11_b)
    w21_x = w21_x - step_lin_w_x * loss_deriv_lin_w11_x(x1, w21_x, w22_x, w_2b):

    x2 = tanh(w12_x * x + w12_b)
    w22_x = w22_x - step_lin_w_x * loss_deriv_lin_w11_x(x2, w21_x, w22_x, w_2b):

    w2_b = w2_b - step_lin_w_b * loss_deriv_lin_w2_b(x2, w21_x, w22_x, w_2b):
        
        
    ax3.scatter(i, w_x, color = 'r', s= 5)
    print "w_x = " + str(w_x)
    w_b = w_b - step_w_b * loss_deriv_w_b(w_x, x, w_b)
    ax4.scatter(i, w_b, color = 'b', s= 5)
    print "w_b = " + str(w_b) 
    
    z = pred(w_x, x, w_b)
    ax1.clear()
    ax1.plot(x, y, color = 'r')
    ax1.plot(x, z, color = 'b')
    
    fig.canvas.draw()
# Out:
#   File "<ipython-input-7-8824f0ea75e0>", line 6
#     w21_x = w21_x - step_lin_w_x * loss_deriv_lin_w11_x(x1, w21_x, w22_x, w_2b):
#                                                                                ^
# SyntaxError: invalid syntax
